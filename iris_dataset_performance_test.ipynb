# %%
from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
performance_values = {}
k = 1
while k <= 25:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    predictions = knn.predict(x_test)
    scores = metrics.accuracy_score(y_test, predictions)
    performance_values[k] = round(scores,4)
    k+=1

print(performance_values)
# Out:
# {1: 0.9211, 2: 0.9211, 3: 0.9211, 4: 0.9211, 5: 0.9474, 6: 0.9211, 7: 0.9474, 8: 0.9474, 9: 0.9474, 10: 0.9211, 11: 0.9474, 12: 0.9211, 13: 0.9474, 14: 0.9474, 15: 0.9211, 16: 0.9474, 17: 0.9211, 18: 0.9474, 19: 0.9211, 20: 0.9211, 21: 0.8947, 22: 0.8947, 23: 0.8947, 24: 0.8947, 25: 0.8947}

# %%
import matplotlib.pyplot as plt

plt.plot(list(performance_values.keys()),list(performance_values.values()))
plt.xlabel('Valores de K')
plt.ylabel('Performance')
plt.show()
